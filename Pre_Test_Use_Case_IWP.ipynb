# %%
import pandas as pd
import  statistics as st

# %%
churn_db=pd.read_csv("D:\Learn_Python\churn.csv", encoding='latin1')

# %%
churn_db.columns
# Out:
# Index(['state', 'account_length', 'area_code', 'phone_number', 'Area_Phone',
#        'international_plan', 'voice_mail_plan', 'number_vmail_messages',
#        'total_day_minutes', 'total_day_calls', 'total_day_charge',
#        'total_eve_minutes', 'total_eve_calls', 'total_eve_charge',
#        'total_night_minutes', 'total_night_calls', 'total_night_charge',
#        'total_intl_minutes', 'total_intl_calls', 'total_intl_charge',
#        'number_customer_service_calls', 'class', 'Total_charge'],
#       dtype='object')

# %%
print (len(churn_db.columns))
print (len(churn_db))
# Out:
# 21
# 5000

# %%
churn_db.corr(method='pearson')
# Out:
#                                   state  account_length  area_code  \
# state                          1.000000        0.010334   0.013858
# account_length                 0.010334        1.000000  -0.018054
# area_code                      0.013858       -0.018054   1.000000
# phone_number                   0.017054        0.004918  -0.011648
# international_plan             0.007422        0.014681   0.032107
# voice_mail_plan               -0.030075       -0.006650  -0.003006
# number_vmail_messages         -0.027282       -0.014575  -0.003399
# total_day_minutes              0.007334       -0.001017  -0.019118
# total_day_calls               -0.008166        0.028240  -0.019314
# total_day_charge               0.007334       -0.001019  -0.019119
# total_eve_minutes              0.003900       -0.009591   0.007098
# total_eve_calls               -0.005458        0.009143  -0.012300
# total_eve_charge               0.003896       -0.009587   0.007114
# ...

# %%
day_minutes=churn_db['total_day_minutes'].sum()
day_charge=churn_db['total_day_charge'].sum()
cost_perminutes_day=day_minutes/day_charge
print ("Cost_perminutes_day:", cost_perminutes_day)

night_minutes=churn_db['total_night_minutes'].sum()
night_charge=churn_db['total_night_charge'].sum()
cost_perminutes_night=night_minutes/night_charge
print ("Cost_perminutes_night:", cost_perminutes_night)

eve_minutes=churn_db['total_eve_minutes'].sum()
eve_charge=churn_db['total_eve_charge'].sum()
cost_perminutes_eve=eve_minutes/eve_charge
print ("Cost_perminutes_eve:", cost_perminutes_eve)
# Out:
# Cost_perminutes_day: 5.88224642433321
# Cost_perminutes_night: 22.22195336920636
# Cost_perminutes_eve: 11.764557981255427

# %%
churn_db.describe()
# Out:
#             state  account_length    area_code  phone_number  \
# count  5000.00000      5000.00000  5000.000000   5000.000000
# mean     25.99840       100.25860   436.911400   2499.500000
# std      14.80348        39.69456    42.209182   1443.520003
# min       0.00000         1.00000   408.000000      0.000000
# 25%      13.00000        73.00000   408.000000   1249.750000
# 50%      26.00000       100.00000   415.000000   2499.500000
# 75%      39.00000       127.00000   415.000000   3749.250000
# max      50.00000       243.00000   510.000000   4999.000000
#
#        international_plan  voice_mail_plan  number_vmail_messages  \
# count         5000.000000      5000.000000            5000.000000
# mean             0.094600         0.264600               7.755200
# std              0.292691         0.441164              13.546393
# min              0.000000         0.000000               0.000000
# 25%              0.000000         0.000000               0.000000
# ...
